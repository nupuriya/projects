# %%
# !pip install numpy
# !pip install pandas

# %%
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# # Stack Overflow Developer Survey 2022

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_something = pd.read_csv(r'C:\Users\galph\Desktop\Nupur_Python_Projects\survey_results_public.csv')

# %%
df_something.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df_something
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
df_something.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
# ...

# %%
df_schema=pd.read_csv(r'C:\Users\galph\Downloads\stack-overflow-developer-survey-2022\survey_results_schema.csv',index_col='qname').question
df_schema
# Out:
# qname
# S0             <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo                                       Browser Meta Info
# S1             <span style="font-size:22px; font-family: aria...
# MainBranch     Which of the following options best describes ...
# Employment     Which of the following best describes your cur...
#                                      ...
# Frequency_2    Interacting with people outside of your immedi...
# Frequency_3    Encountering knowledge silos (where one indivi...
# TrueFalse_1    Are you involved in supporting new hires durin...
# TrueFalse_2    Do you use learning resources provided by your...
# TrueFalse_3    Does your employer give you time to learn new ...
# Name: question, Length: 79, dtype: object

# %%
df_schema['SOAccount']
# Out:
# 'Do you have a Stack Overflow account?'

# %%
column_names = list(df_something.columns.values)

# %%
column_names
# Out:
# ['ResponseId',
#  'MainBranch',
#  'Employment',
#  'RemoteWork',
#  'CodingActivities',
#  'EdLevel',
#  'LearnCode',
#  'LearnCodeOnline',
#  'LearnCodeCoursesCert',
#  'YearsCode',
#  'YearsCodePro',
#  'DevType',
#  'OrgSize',
#  'PurchaseInfluence',
#  'BuyNewTool',
#  'Country',
#  'Currency',
#  'CompTotal',
#  'CompFreq',
#  'LanguageHaveWorkedWith',
#  'LanguageWantToWorkWith',
#  'DatabaseHaveWorkedWith',
#  'DatabaseWantToWorkWith',
#  'PlatformHaveWorkedWith',
#  'PlatformWantToWorkWith',
#  'WebframeHaveWorkedWith',
#  'WebframeWantToWorkWith',
#  'MiscTechHaveWorkedWith',
#  'MiscTechWantToWorkWith',
#  'ToolsTechHaveWorkedWith',
#  'ToolsTechWantToWorkWith',
#  'NEWCollabToolsHaveWorkedWith',
#  'NEWCollabToolsWantToWorkWith',
#  'OpSysProfessional use',
#  'OpSysPersonal use',
#  'VersionControlSystem',
#  'VCInteraction',
#  'VCHostingPersonal use',
#  'VCHostingProfessional use',
#  'OfficeStackAsyncHaveWorkedWith',
#  'OfficeStackAsyncWantToWorkWith',
# ...

# %%
 df_something.TimeSearching.unique()
# Out:
# array([nan, '15-30 minutes a day', '30-60 minutes a day',
#        '60-120 minutes a day', 'Less than 15 minutes a day',
#        'Over 120 minutes a day'], dtype=object)

# %%
df_something['YearsCode']=pd.to_numeric(df_something.YearsCode, errors='coerce')
df_something['YearsCodePro']=pd.to_numeric(df_something.YearsCodePro, errors='coerce')

# %%
df_something.YearsCode.unique()
# Out:
# array([nan, 14., 20.,  8., 15.,  3.,  1.,  6., 37.,  5., 12., 22., 11.,
#         4.,  7., 13., 36.,  2., 25., 10., 40., 16., 27., 24., 19.,  9.,
#        17., 18., 26., 29., 30., 32., 48., 45., 38., 39., 28., 23., 43.,
#        21., 41., 35., 50., 33., 31., 34., 46., 44., 42., 47., 49.])

# %%
df_sample=df_something.sample(n=10)

# %%
df_something.describe()
# Out:
#          ResponseId     YearsCode  YearsCodePro     CompTotal  \
# count  73268.000000  69746.000000  49820.000000  3.842200e+04
# mean   36634.500000     12.403951     10.268727  2.342434e+52
# std    21150.794099      9.722896      8.576772  4.591478e+54
# min        1.000000      1.000000      1.000000  0.000000e+00
# 25%    18317.750000      5.000000      4.000000  3.000000e+04
# 50%    36634.500000     10.000000      8.000000  7.750000e+04
# 75%    54951.250000     17.000000     15.000000  1.540000e+05
# max    73268.000000     50.000000     50.000000  9.000000e+56
#
#        VCHostingPersonal use  VCHostingProfessional use       WorkExp  \
# count                    0.0                        0.0  36769.000000
# mean                     NaN                        NaN     10.242378
# std                      NaN                        NaN      8.706850
# min                      NaN                        NaN      0.000000
# ...

# %% [markdown]
# ## Developer Profile

# %%
df_gender=df_something['Gender'].value_counts()
df_gender
# Out:
# Man                                                                                   64607
# Woman                                                                                  3399
# Prefer not to say                                                                      1172
# Non-binary, genderqueer, or gender non-conforming                                       704
# Or, in your own words:                                                                  279
# Man;Non-binary, genderqueer, or gender non-conforming                                   235
# Man;Or, in your own words:                                                              171
# Woman;Non-binary, genderqueer, or gender non-conforming                                 160
# Man;Woman;Non-binary, genderqueer, or gender non-conforming                              31
# Man;Woman                                                                                24
# ...

# %%
df_something.where(~(df_something.Gender.str.contains(';', na=False)),np.nan, inplace=True)

# %%
df_gender=df_something['Gender'].value_counts()
df_gender
# Out:
# Man                                                  64607
# Woman                                                 3399
# Prefer not to say                                     1172
# Non-binary, genderqueer, or gender non-conforming      704
# Or, in your own words:                                 279
# Name: Gender, dtype: int64

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(df_gender,labels=df_gender.index,textprops={'fontsize': 10},autopct='%1.1f%%')
plt.title(df_schema['Gender'])
# Out:
# Text(0.5, 1.0, 'Which of the following describe you, if any? Please check all that apply.')

# %%
import matplotlib

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size']=12
matplotlib.rcParams['figure.figsize']=(9,5)
matplotlib.rcParams['figure.facecolor']='pink'

# %%
top_countries=df_something.Country.value_counts().head(15)
top_countries
# Out:
# United States of America                                13321
# India                                                    6618
# Germany                                                  5342
# United Kingdom of Great Britain and Northern Ireland     4132
# Canada                                                   2459
# France                                                   2306
# Brazil                                                   2088
# Poland                                                   1719
# Netherlands                                              1539
# Spain                                                    1511
# Italy                                                    1504
# Australia                                                1449
# Russian Federation                                       1215
# Turkey                                                   1014
# Sweden                                                   1008
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
plt.title('Where do you live?')
sns.barplot(top_countries.index, top_countries);
# Out:
# C:\Users\galph\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_schema['WorkExp']
# Out:
# 'How many years of working experience do you have?'

# %%
plt.figure(figsize=(12,6))
plt.title(df_schema.YearsCode)
plt.xlabel('YearsCode')
plt.ylabel('Number of Respondents')
plt.hist(df_something.YearsCode, bins=np.arange(10,70,10), color='green')
# Out:
# (array([20414.,  8837.,  4016.,  1684.,    68.]),
#  array([10, 20, 30, 40, 50, 60]),
#  <BarContainer object of 5 artists>)

# %%
df_something.EdLevel.unique()
# Out:
# array([nan, 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Some college/university study without earning a degree',
#        'Something else', 'Primary/elementary school',
#        'Other doctoral degree (Ph.D., Ed.D., etc.)',
#        'Associate degree (A.A., A.S., etc.)',
#        'Professional degree (JD, MD, etc.)'], dtype=object)

# %%
df_edlvl=df_something['EdLevel'].value_counts()
df_edlvl
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          30050
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       15394
# Some college/university study without earning a degree                                 9194
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     7769
# Associate degree (A.A., A.S., etc.)                                                    2221
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             2152
# Primary/elementary school                                                              1767
# Something else                                                                         1222
# Professional degree (JD, MD, etc.)                                                     1110
# Name: EdLevel, dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.countplot(y=df_something.EdLevel);
plt.xticks(rotation=75)
plt.title(df_schema['EdLevel'])
plt.ylabel(None);

# %%
df_something.YearsCodePro.unique()
# Out:
# array([nan,  5., 17.,  3.,  6., 30.,  2., 10., 15.,  4., 22., 20., 40.,
#         9., 14., 21.,  7., 18., 25.,  8., 12., 45.,  1., 19., 28., 24.,
#        11., 23., 32., 27., 16., 44., 26., 37., 46., 13., 31., 39., 34.,
#        38., 35., 29., 42., 36., 33., 43., 41., 48., 50., 47., 49.])

# %%
plt.figure(figsize=(12,10))
sns.countplot(x=df_something.YearsCodePro);
plt.xticks(rotation=90)
plt.title(df_schema['YearsCodePro'])
plt.ylabel(None)
plt.xlabel(None);

# %%
df_something.Ethnicity.value_counts()
# Out:
# European                                                          14527
# White                                                             13476
# White;European                                                     8582
# Indian                                                             5226
# Asian                                                              3332
#                                                                   ...
# Indian;European;Caribbean;Multiracial                                 1
# European;Asian;East Asian;Southeast Asian;Multiracial;Biracial        1
# African;Asian;Multiracial                                             1
# Indian;European;African;Multiracial                                   1
# White;European;North African;Hispanic or Latino/a                     1
# Name: Ethnicity, Length: 1022, dtype: int64

# %%
df_something.where(~(df_something.Ethnicity.str.contains(';', na=False)),np.nan, inplace=True)

# %%
plt.figure(figsize=(16,14))
(df_something.Ethnicity.value_counts(normalize=True, ascending=True)*100).plot(kind='barh', color='g')
plt.title(df_schema['Ethnicity'])
plt.xlabel(None)
plt.show()

# %%
df_this=df_something.Sexuality.value_counts()

# %%
df_that=df_this.head(n=6)

# %%
plt.figure(figsize=(14,6))
sns.barplot(df_that.index, df_that);
plt.title(df_schema['Sexuality'])
plt.xlabel(None)
plt.ylabel(None)
plt.show()
# Out:
# C:\Users\galph\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(16,6))
(df_something.Trans.value_counts(normalize=True, ascending=True)*100).plot(kind='barh', color='green')
plt.title(df_schema['Trans'])
plt.xlabel('Percentage')
plt.show()

# %% [markdown]
# ## Technology

# %%
df_x=df_something['PurchaseInfluence']
df_y=df_x.value_counts()

# %%
fig = plt.figure(figsize =(10, 5))
plt.title(df_schema.PurchaseInfluence)
plt.pie(df_y,labels=df_y.index,textprops={'fontsize': 10},autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d83c7091f0>,
# ...
#  [Text(0.2321478434068604, 1.075224338824947, 'I have some influence'),
#   Text(-0.8870400861357196, -0.6505074062517162, 'I have little or no influence'),
#   Text(0.8230598534541594, -0.7297756351317971, 'I have a great deal of influence')],
#  [Text(0.126626096403742, 0.5864860029954255, '43.2%'),
#   Text(-0.4838400469831197, -0.3548222215918452, '33.7%'),
#   Text(0.44894173824772327, -0.3980594373446166, '23.1%')])

# %%
df_k=df_something['VCInteraction'].value_counts()
df_l=df_k.head(n=8)
df_l
# Out:
# Command-line                                                                                                  13038
# Code editor;Command-line                                                                                      11797
# Code editor;Command-line;Version control hosting service web GUI                                               4832
# Code editor;Command-line;Version control hosting service web GUI;Dedicated version control GUI application     2975
# Code editor                                                                                                    2850
# Command-line;Dedicated version control GUI application                                                         2787
# Dedicated version control GUI application                                                                      2565
# Command-line;Version control hosting service web GUI                                                           2350
# Name: VCInteraction, dtype: int64

# %%
plt.figure(figsize=(16,12))
df_l.plot.bar(title=df_schema.VCInteraction, color='orange')
# Out:
# <AxesSubplot:title={'center':'How do you interact with your version control system? Select all that apply.'}>

# %%
df_a=df_something['DevType']
df_b=df_a.value_counts()
df_b.head()
# Out:
# Developer, full-stack                                             5549
# Developer, back-end                                               3936
# Developer, front-end                                              1825
# Developer, front-end;Developer, full-stack;Developer, back-end    1267
# Developer, mobile                                                 1140
# Name: DevType, dtype: int64

# %%
fig = plt.figure(figsize =(16, 6))
plt.title(df_schema.DevType)
plt.pie(df_b.head(),labels=df_b.head().index,textprops={'fontsize': 10},autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d83cb0b610>,
# ...
#  [Text(0.324981488381354, 1.050898202591212, 'Developer, full-stack'),
#   Text(-1.0503384395137472, -0.32678611121011075, 'Developer, back-end'),
#   Text(0.05527570205456716, -1.0986103025014715, 'Developer, front-end'),
#   Text(0.7565607756506236, -0.7985084800720196, 'Developer, front-end;Developer, full-stack;Developer, back-end'),
#   Text(1.0627191652308294, -0.28395065742323866, 'Developer, mobile')],
#  [Text(0.17726263002619305, 0.5732172014133883, '40.5%'),
#   Text(-0.5729118760984074, -0.1782469697509695, '28.7%'),
#   Text(0.03015038293885481, -0.5992419831826208, '13.3%'),
#   Text(0.4126695139912492, -0.43555008003928336, '9.2%'),
#   Text(0.5796649992168159, -0.154882176776312, '8.3%')])

# %%
df_c=df_something['LanguageHaveWorkedWith'].value_counts()
df_d=df_c.head()
df_d
# Out:
# HTML/CSS;JavaScript;TypeScript    885
# Python                            723
# HTML/CSS;JavaScript               695
# HTML/CSS;JavaScript;PHP;SQL       549
# Java                              416
# Name: LanguageHaveWorkedWith, dtype: int64

# %%
df_e=df_something['LanguageWantToWorkWith'].value_counts()
df_f=df_e.head()
df_f
# Out:
# Python                            772
# HTML/CSS;JavaScript;TypeScript    686
# Rust                              600
# C#                                421
# Go                                398
# Name: LanguageWantToWorkWith, dtype: int64

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16,8))
ax1.bar(df_d.index, df_d, color='orange')
ax1.set_xlabel(None)
ax1.set_ylabel(None)
ax1.set_title('Language Have Worked With')
ax1.tick_params(axis='x', labelsize=9, rotation=90)

ax2.bar(df_f.index, df_f, color='orange')
ax2.set_xlabel(None)
ax2.set_ylabel(None)
ax2.set_title('Language Want To Work With')
ax2.tick_params(axis='x', labelsize=9, rotation=90)

# %%
df_something['Blockchain']
# Out:
# 0                     NaN
# 1        Very unfavorable
# 2        Very unfavorable
# 3        Very unfavorable
# 4             Unfavorable
#                ...
# 73263      Very favorable
# 73264              Unsure
# 73265    Very unfavorable
# 73266         Indifferent
# 73267           Favorable
# Name: Blockchain, Length: 73268, dtype: object

# %%
plt.figure(figsize=(16,6))
(df_something.Blockchain.value_counts(normalize=True, ascending=True)*100).plot(kind='barh', color='orange')
plt.title(df_schema['Blockchain'])
plt.xlabel('Percentage')
plt.show()

# %% [markdown]
# ## Work

# %%
plt.figure(figsize=(12,6))
plt.title(df_schema.WorkExp)
plt.xlabel('WorkExp')
plt.ylabel('Number of Respondents')
plt.hist(df_something.WorkExp, bins=np.arange(10,70,5), color='blue')
# Out:
# (array([4466., 2529., 1914., 1023.,  596.,  304.,  196.,   52.,   43.,
#            0.,    0.]),
#  array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65]),
#  <BarContainer object of 11 artists>)

# %%
df_g=df_something['Employment'].value_counts()
df_h=df_g.head(n=6)
df_h
# Out:
# Employed, full-time                                                         31796
# Student, full-time                                                           4600
# Independent contractor, freelancer, or self-employed                         3641
# Employed, full-time;Independent contractor, freelancer, or self-employed     2407
# Not employed, but looking for work                                           1318
# Employed, part-time                                                           811
# Name: Employment, dtype: int64

# %%
plt.figure(figsize=(16,9))
df_h.plot.barh(title='Employeement Status', color='blue')
# Out:
# <AxesSubplot:title={'center':'Employeement Status'}>

# %%
df_j=df_something['RemoteWork'].value_counts()
df_j
# Out:
# Fully remote                            18190
# Hybrid (some remote, some in-person)    18066
# Full in-person                           6455
# Name: RemoteWork, dtype: int64

# %%
fig = plt.figure(figsize =(4, 16))
plt.title(df_schema.RemoteWork)
plt.pie(df_j,labels=df_j.index,textprops={'fontsize': 10},autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d83be01430>,
# ...
#  [Text(0.25381299617957487, 1.0703172253917748, 'Fully remote'),
#   Text(-0.7150401217251456, -0.8358933091748547, 'Hybrid (some remote, some in-person)'),
#   Text(0.9783250081622683, -0.5028719304199607, 'Full in-person')],
#  [Text(0.1384434524615863, 0.5838093956682407, '42.6%'),
#   Text(-0.3900218845773521, -0.4559418050044661, '42.3%'),
#   Text(0.5336318226339645, -0.2742937802290695, '15.1%')])

# %%
df_k=df_something['OrgSize'].value_counts()

# %%
plt.figure(figsize=(16,9))
df_k.plot.barh(title='Organization Size', color='blue')
# Out:
# <AxesSubplot:title={'center':'Organization Size'}>
